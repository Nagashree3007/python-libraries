# %% [markdown]
# '''
#
# @Author: Nagashree C R <br>
# @Date: 2024-08-02 <br>
# @Last Modified by: Nagashree C R <br>
# @Last Modified: 2024-08-02 <br>
# @Title : Python program to display a bar chart
#
# '''

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
programming_languages = ['Python', 'JavaScript', 'Java', 'C#', 'C++', 'PHP']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(programming_languages, popularity)

# Add titles and labels
plt.title('Popularity of Programming Languages')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity (%)')

# Display the bar chart
plt.show()
