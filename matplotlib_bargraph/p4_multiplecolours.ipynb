# %% [markdown]
# '''
#
# @Author: Nagashree C R<br>
# @Date: 2024-08-02<br>
# @Last Modified by: Nagashree C R<br>
# @Last Modified: 2024-08-02 <br>
# @Title : Python program to display a horizontal bar chart to display a bar chart of the popularity of programming
# Languages.(Use multiple color).
#
# '''

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

# Define a list of colors for each bar
colors = ['skyblue', 'lightgreen', 'lightcoral', 'lightgoldenrodyellow', 'lightsalmon', 'lightpink']

# Create the bar chart with different colors
plt.figure(figsize=(10, 6))
plt.bar(programming_languages, popularity, color=colors)

# Add titles and labels
plt.title('Popularity of Programming Languages')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity (%)')

# Display the bar chart
plt.show()
