# %% [markdown]
# '''
#
# @Author: Nagashree C R<br>
# @Date: 2024-08-02<br>
# @Last Modified by: Nagashree C R<br>
# @Last Modified: 2024-08-02 <br>
# @Title : Python program to display text on the graph.
#
# '''

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(programming_languages, popularity, color='skyblue')

# Add titles and labels
plt.title('Popularity of Programming Languages')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity (%)')

# Add text labels above each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', 
             ha='center', va='bottom', fontsize=10, color='black')

# Display the bar chart
plt.show()
