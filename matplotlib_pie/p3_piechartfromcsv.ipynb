# %% [markdown]
#  '''
#
# @Author: Nagashree C R
# @Date: 2024-08-05
# @Last Modified by: Nagashree C R
# @Last Modified: 2024-08-05
# @Title : Python programming to create a pie chart of gold medal achievements of five most  successful countries in 2016 Summer Olympics. Read the data from a csv file.
#
# '''

# %%
import matplotlib.pyplot as plt
import pandas as pd
df =  pd.read_csv('medal.csv')
print(df)
country_data = df["country"]
medal_data = df["gold_medal"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(medal_data, labels=country_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
plt.show()
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
# 4        Germany          17

# %%
d={
'country':['United States', 'Great Britain',' China', 'Russia'] ,
'gold_medal':[46,27,26,19]
}
import pandas as pd
df=pd.DataFrame(d)
print(df)
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
