# %% [markdown]
# @Author: Nagashree C R
# @Date: 2024-08-06
# @Last Modified by: Nagashree C R
# @Last Modified: 2024-08-06
# @Title : program to draw box plot

# %% [markdown]
# 1.Write a program to draw box plot of life expectancy by continent for a data set given in a
# url
# https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url='https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv'
data=pd.read_csv(url)
plt.figure(figsize=(6,10))
sns.boxplot(x='continent',y='lifeExp',data=data,hue='continent',palette='cool')

plt.title('Box Plot of Life Expectancy by Continent')
plt.xlabel('Continent')
plt.ylabel('Life Expectancy')

plt.show()

# %% [markdown]
#  Write a program to draw a box plot of day by tips for a dataset given in a url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
data = pd.read_csv(url)
print(data.head)

# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='day', y='tip', data=data, hue='day',palette='pastel')

# Customize the plot
plt.title('Box Plot of Tips by Day')
plt.xlabel('Day')
plt.ylabel('Tip')
# Show the plot
plt.show()
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>
